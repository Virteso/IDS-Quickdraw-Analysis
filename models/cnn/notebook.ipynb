# %%
import numpy as np

import cnn
import funfunctions as fun
import cnnfunctions as fs
import tensorflow as tf

import config

np.random.seed(config.RANDOM_SEED)

# %%
x_train, x_test, y_train, y_test = fs.gather_data()
# Out:
# gathering data.
# 	 loading file angel.npy
# 		 storing...
# 	 loading file airplane.npy
# 		 storing...
# 	 loading file bed.npy
# 		 storing...
# 	 loading file whale.npy
# 		 storing...
# 	 loading file shovel.npy
# 		 storing...
# 	 loading file tractor.npy
# 		 storing...
# 	 loading file panda.npy
# 		 storing...
# 	 loading file bat.npy
# 		 storing...
# 	 loading file camel.npy
# 		 storing...
# 	 loading file cow.npy
# 		 storing...
# 	 loading file ant.npy
# 		 storing...
# 	 loading file bicycle.npy
# 		 storing...
# 	 loading file bear.npy
# 		 storing...
# 	 loading file door.npy
# 		 storing...
# 	 loading file fan.npy
# 		 storing...
# 	 loading file flying saucer.npy
# 		 storing...
# 	 loading file foot.npy
# 		 storing...
# 	 loading file lipstick.npy
# 		 storing...
# 	 loading file postcard.npy
# 		 storing...
# 	 loading file popsicle.npy
# 		 storing...
# 	 loading file rainbow.npy
# 		 storing...
# 	 loading file sock.npy
# 		 storing...
# ...

# %%
fun.display_picture(np.reshape(x_train[3], (28, 28)))

# %%
model = fs.create_model()
model.summary()
history = fs.train_model(model, x_train, x_test, y_train, y_test)
# Out:
# creating model.
# 	 compiling model...
# 	 done compiling.
# 2024-12-09 02:27:59.600644: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model = tf.keras.models.load_model("89_75.keras")
# Out:
# 2024-12-12 16:55:13.104205: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
model.summary()

testangel = np.load("../../test.npy")
testangel = np.reshape(testangel / 255.0, (1, 28, 28, 1))
picture = np.reshape((np.load("../../data/numpy_bitmap/panda.npy")[11]) / 255.0, (1, 28, 28, 1))
#test = np.reshape(np.load("shovel.npy") / 255.0, (1, 28, 28, 1))
print(testangel.shape)
#print(test.shape)
#pic = np.reshape(x_train[i], (1, 28, 28))
pred = fs.get_class_probas(model(testangel)[0])
print(pred)
print(max(pred, key=pred.get))
#fun.display_picture(np.reshape(pic, (28, 28)))
fun.display_picture(
    np.reshape(testangel, (28, 28))
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 128)      │        73,856 │
# ...

# %%
#model.save("ulmeCNN.keras")

# %%
#model.save("./4000_10_some.keras")

# %%
import config
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(config.DRAWING_NAMES[y_train[i]])
#plt.show()
plt.savefig("failinimi.pdf")

# %%
model.evaluate(x_test, y_test)
# Out:
# 1641/1641 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.8395 - loss: 0.6733
# [0.6759425401687622, 0.8393744826316833]
